# %% [markdown]
# https://datos.cdmx.gob.mx/dataset/incidentes-viales-c5

# %%
import pandas as pd               # Para la manipulación y análisis de datos
import numpy as np                # Para crear vectores y matrices n dimensionales
import matplotlib.pyplot as plt   # Para la generación de gráficas a partir de los datos
import seaborn as sns             # Para la visualización de datos basado en matplotlib
# %matplotlib inline

# %%
Data = pd.read_csv("inci.csv", index_col=0, encoding='latin-1')
Data
# Out:
# /home/erick/.local/lib/python3.6/site-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                    folio fecha_creacion hora_creacion dia_semana fecha_cierre  \
# 1        C4/131231/03346     2013-12-31      22:44:53     martes   2014-01-01
# 2        C4/140101/04189     2014-01-01      21:45:43  miercoles   2014-01-01
# 3        C4/140101/03736     2014-01-01      19:47:28  miercoles   2014-01-01
# 4        C4/131231/03218     2013-12-31      22:14:37     martes   2014-01-01
# 5        C4/140101/03294     2014-01-01      18:01:43  miercoles   2014-01-01
# ...                  ...            ...           ...        ...          ...
# 1552438  C5/210901/00711     2021-09-01      16:18:40  miercoles   2021-09-01
# 1552439  C5/210325/01187     2021-03-26      00:16:18     jueves   2021-09-08
# 1552440  C5/210914/00316     2021-09-14      13:51:05     martes   2021-09-14
# 1552441  C5/210927/01789     2021-09-27      17:00:24      lunes   2021-09-27
# 1552442  C5/210928/00568     2021-09-28      14:15:56     martes   2021-09-28
#
#         hora_cierre                           incidente_c4  \
# 1          02:11:35        accidente-choque sin lesionados
# 2          23:55:59        accidente-choque con lesionados
# 3          20:27:26        accidente-choque sin lesionados
# 4          02:09:56        accidente-choque sin lesionados
# 5          18:21:59        accidente-choque con lesionados
# ...             ...                                    ...
# 1552438    16:20:56  mi ciudad-calle-incidente de tránsito
# 1552439    23:31:32                 accidente-motociclista
# 1552440    13:55:23  mi ciudad-calle-incidente de tránsito
# 1552441    18:40:12  mi ciudad-calle-incidente de tránsito
# 1552442    21:51:55   mi ciudad-taxi-incidente de tránsito
#
#            delegacion_inicio    latitud   longitud  ano_cierre  \
# 1                 IZTAPALAPA  19.314690 -99.071130        2014
# 2             ALVARO OBREGON  19.363360 -99.191040        2014
# 3                    TLAHUAC  19.295440 -99.054880        2014
# 4                 IZTAPALAPA  19.326870 -99.068880        2014
# 5                   COYOACAN  19.310150 -99.108050        2014
# ...                      ...        ...        ...         ...
# 1552438        BENITO JUAREZ  19.357647 -99.153143        2021
# 1552439           CUAUHTEMOC  19.458790 -99.146880        2021
# 1552440           CUAUHTEMOC  19.416881 -99.165336        2021
# 1552441  VENUSTIANO CARRANZA  19.407986 -99.077291        2021
# 1552442             COYOACAN  19.303679 -99.184620        2021
#
#          clas_con_f_alarma     tipo_entrada    delegacion_cierre  mes_cierre  \
# 1               EMERGENCIA  LLAMADA DEL 066           IZTAPALAPA       Enero
# 2        URGENCIAS MEDICAS  LLAMADA DEL 066       ALVARO OBREGON       Enero
# 3               EMERGENCIA  LLAMADA DEL 066              TLAHUAC       Enero
# 4               EMERGENCIA  LLAMADA DEL 066           IZTAPALAPA       Enero
# 5        URGENCIAS MEDICAS  LLAMADA DEL 066             COYOACAN       Enero
# ...                    ...              ...                  ...         ...
# 1552438         EMERGENCIA      APLICATIVOS        BENITO JUAREZ  Septiembre
# 1552439  URGENCIAS MEDICAS  LLAMADA DEL 911           CUAUHTEMOC  Septiembre
# 1552440         EMERGENCIA      APLICATIVOS           CUAUHTEMOC  Septiembre
# 1552441         EMERGENCIA      APLICATIVOS  VENUSTIANO CARRANZA  Septiembre
# 1552442       FALSA ALARMA      APLICATIVOS             COYOACAN  Septiembre
#
#         codigo_cierre
# 1                   I
# 2                   A
# 3                   A
# 4                   I
# 5                   N
# ...               ...
# 1552438             I
# 1552439             N
# 1552440             I
# 1552441             I
# 1552442             F
#
# [1552442 rows x 16 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1552442 entries, 1 to 1552442
# Data columns (total 16 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   folio              1552442 non-null  object
#  1   fecha_creacion     1552442 non-null  object
#  2   hora_creacion      1552442 non-null  object
#  3   dia_semana         1552442 non-null  object
#  4   fecha_cierre       1552442 non-null  object
#  5   hora_cierre        1552442 non-null  object
#  6   incidente_c4       1552442 non-null  object
#  7   delegacion_inicio  1552269 non-null  object
#  8   latitud            1551999 non-null  float64
#  9   longitud           1552007 non-null  float64
#  10  ano_cierre         1552442 non-null  int64
#  11  clas_con_f_alarma  1552442 non-null  object
#  12  tipo_entrada       1552442 non-null  object
#  13  delegacion_cierre  1552287 non-null  object
#  14  mes_cierre         1552442 non-null  object
#  15  codigo_cierre      1552442 non-null  object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 201.4+ MB
