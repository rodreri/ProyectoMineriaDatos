# %% [markdown]
# https://datos.cdmx.gob.mx/dataset/incidentes-viales-c5

# %%
import pandas as pd               # Para la manipulación y análisis de datos
import numpy as np                # Para crear vectores y matrices n dimensionales
import matplotlib.pyplot as plt   # Para la generación de gráficas a partir de los datos
import seaborn as sns             # Para la visualización de datos basado en matplotlib
# %matplotlib inline

# %%
Data = pd.read_csv("inci.csv", index_col=0, encoding='latin-1')
# Data = pd.read_csv("inci.csv")
Data
# Out:
#                    folio fecha_creacion hora_creacion dia_semana fecha_cierre  \
# 1        C4/131231/03346     2013-12-31      22:44:53     martes   2014-01-01
# 2        C4/140101/04189     2014-01-01      21:45:43  miercoles   2014-01-01
# 3        C4/140101/03736     2014-01-01      19:47:28  miercoles   2014-01-01
# 4        C4/131231/03218     2013-12-31      22:14:37     martes   2014-01-01
# 5        C4/140101/03294     2014-01-01      18:01:43  miercoles   2014-01-01
# ...                  ...            ...           ...        ...          ...
# 1571811  C5/211028/01123          18928      18:21:15     jueves        18928
# 1571812  C5/211028/01168          18928      18:55:41     jueves        18928
# 1571813  C5/211029/01113          18929      19:31:42    viernes        18929
# 1571814  C5/211031/00016          18931      12:12:02    domingo        18931
# 1571815  C5/211031/00076          18931      18:42:35    domingo        18931
#
#         hora_cierre                           incidente_c4  \
# 1          02:11:35        accidente-choque sin lesionados
# 2          23:55:59        accidente-choque con lesionados
# 3          20:27:26        accidente-choque sin lesionados
# 4          02:09:56        accidente-choque sin lesionados
# 5          18:21:59        accidente-choque con lesionados
# ...             ...                                    ...
# 1571811    18:56:16  mi ciudad-calle-incidente de tránsito
# 1571812    18:57:01  mi ciudad-calle-incidente de tránsito
# 1571813    19:34:27  mi ciudad-calle-incidente de tránsito
# 1571814    12:18:15  mi ciudad-calle-incidente de tránsito
# 1571815    18:46:08  mi ciudad-calle-incidente de tránsito
#
#            delegacion_inicio    latitud   longitud  ano_cierre  \
# 1                 IZTAPALAPA  19.314690 -99.071130        2014
# 2             ALVARO OBREGON  19.363360 -99.191040        2014
# 3                    TLAHUAC  19.295440 -99.054880        2014
# 4                 IZTAPALAPA  19.326870 -99.068880        2014
# 5                   COYOACAN  19.310150 -99.108050        2014
# ...                      ...        ...        ...         ...
# 1571811       MIGUEL HIDALGO  19.420158 -99.178352        2021
# 1571812       MIGUEL HIDALGO  19.420166 -99.178436        2021
# 1571813           CUAJIMALPA  19.347461 -99.283261        2021
# 1571814  VENUSTIANO CARRANZA  19.422212 -99.100138        2021
# 1571815           IZTAPALAPA  19.304566 -99.066493        2021
#
#          clas_con_f_alarma     tipo_entrada    delegacion_cierre mes_cierre  \
# 1               EMERGENCIA  LLAMADA DEL 066           IZTAPALAPA      Enero
# 2        URGENCIAS MEDICAS  LLAMADA DEL 066       ALVARO OBREGON      Enero
# 3               EMERGENCIA  LLAMADA DEL 066              TLAHUAC      Enero
# 4               EMERGENCIA  LLAMADA DEL 066           IZTAPALAPA      Enero
# 5        URGENCIAS MEDICAS  LLAMADA DEL 066             COYOACAN      Enero
# ...                    ...              ...                  ...        ...
# 1571811         EMERGENCIA      APLICATIVOS       MIGUEL HIDALGO    Octubre
# 1571812         EMERGENCIA      APLICATIVOS       MIGUEL HIDALGO    Octubre
# 1571813         EMERGENCIA      APLICATIVOS           CUAJIMALPA    Octubre
# 1571814         EMERGENCIA      APLICATIVOS  VENUSTIANO CARRANZA    Octubre
# 1571815         EMERGENCIA      APLICATIVOS           IZTAPALAPA    Octubre
#
#         codigo_cierre
# 1                   I
# 2                   A
# 3                   A
# 4                   I
# 5                   N
# ...               ...
# 1571811             I
# 1571812             I
# 1571813             I
# 1571814             I
# 1571815             I
#
# [1571815 rows x 16 columns]

# %%
# Data.info()
Data2 = Data.drop(['incidente_c4','folio','fecha_cierre','hora_cierre','ano_cierre','delegacion_cierre','clas_con_f_alarma','tipo_entrada','mes_cierre'], axis=1)

# %%
# Data2.to_csv('incid.csv')
Data2
# Out:
#         fecha_creacion hora_creacion dia_semana    delegacion_inicio  \
# 1           2013-12-31      22:44:53     martes           IZTAPALAPA
# 2           2014-01-01      21:45:43  miercoles       ALVARO OBREGON
# 3           2014-01-01      19:47:28  miercoles              TLAHUAC
# 4           2013-12-31      22:14:37     martes           IZTAPALAPA
# 5           2014-01-01      18:01:43  miercoles             COYOACAN
# ...                ...           ...        ...                  ...
# 1571811          18928      18:21:15     jueves       MIGUEL HIDALGO
# 1571812          18928      18:55:41     jueves       MIGUEL HIDALGO
# 1571813          18929      19:31:42    viernes           CUAJIMALPA
# 1571814          18931      12:12:02    domingo  VENUSTIANO CARRANZA
# 1571815          18931      18:42:35    domingo           IZTAPALAPA
#
#            latitud   longitud codigo_cierre
# 1        19.314690 -99.071130             I
# 2        19.363360 -99.191040             A
# 3        19.295440 -99.054880             A
# 4        19.326870 -99.068880             I
# 5        19.310150 -99.108050             N
# ...            ...        ...           ...
# 1571811  19.420158 -99.178352             I
# 1571812  19.420166 -99.178436             I
# 1571813  19.347461 -99.283261             I
# 1571814  19.422212 -99.100138             I
# 1571815  19.304566 -99.066493             I
#
# [1571815 rows x 7 columns]
